# %%
import numpy as np
import pandas as pd
import re
import nltk
df = pd.read_csv("AI_CRJ700.csv",header=0)

# %%
df1 = pd.read_csv("FI_CRJ700.csv",header=0)
# Out:
# D:\Programs\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (16,17,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df1 = df1[['ATA_SYMPTOM', 'ATA_CAUSE', 'INTERRUPTION_REASON', 'CORRECTIVE_ACTION']]

# %%
df = df[['ATA_SYMPTOM', 'ATA_CAUSE', 'INTERRUPTION_REASON', 'CORRECTIVE_ACTION']]
df2 = df.append(df1, ignore_index=True)

# %%
df2['ATA_SYM_4'] = df2['ATA_SYMPTOM'].astype(str).str[:4]

# %%
df2['ATA_CAUSE_4'] = df2['ATA_CAUSE'].astype(str).str[:4]

# %% [markdown]
# ATA_SYMPTOM

# %%
len(df)
# Out:
# 25696

# %%
len(df1)
# Out:
# 369121

# %%
len(df2)
# Out:
# 394817

# %%
df2['features'] = df2['INTERRUPTION_REASON'].str.cat(df2['CORRECTIVE_ACTION'], sep='  ',na_rep=' ')

# %%
df2.head()
# Out:
#    ATA_SYMPTOM  ATA_CAUSE                                INTERRUPTION_REASON  \
# 0       3081.0     308102                          ICE DET (X) FAIL - STATUS
# 1       2431.0     243101                              TRU FAN FAIL - STATUS
# 2       3613.0     361315                                ISOL FAIL - CAUTION
# 3       3022.0     302201  Incident: RTRN L COWL ANTI ICE CAUTION MSG. L ...
# 4     213108.0     213108  Incident: RTRN OVBD COOL CAUTION MESSAGE DISPL...
#
#                                    CORRECTIVE_ACTION  Unnamed: 0 FI_DATE  \
# 0                   DEFERRED - REPLACED ICE DETECTOR         NaN     NaN
# 1                            DEFERRED - REPLACED TRU         NaN     NaN
# 2                           REPLACED ISOLATION VALVE         NaN     NaN
# 3  (Resolved On W/O: 684248 Taskcard: NR-00001 ) ...         NaN     NaN
# 4  (Resolved On W/O: 684350 Taskcard: NR-00001 ) ...         NaN     NaN
#
#   AC_MODEL  AC_SN OPERATOR_CODE DELAY  ... SCHED_DEPARTURE_TIME  \
# 0      NaN    NaN           NaN   NaN  ...                  NaN
# 1      NaN    NaN           NaN   NaN  ...                  NaN
# 2      NaN    NaN           NaN   NaN  ...                  NaN
# 3      NaN    NaN           NaN   NaN  ...                  NaN
# 4      NaN    NaN           NaN   NaN  ...                  NaN
#
#    ACTUAL_DEPARTURE_TIME INTERRUPTION_CODE FI_ID  EDITED_BY EDIT_DATE  \
# 0                    NaN               NaN   NaN        NaN       NaN
# 1                    NaN               NaN   NaN        NaN       NaN
# 2                    NaN               NaN   NaN        NaN       NaN
# 3                    NaN               NaN   NaN        NaN       NaN
# 4                    NaN               NaN   NaN        NaN       NaN
#
#                                             features features_1 ATA_SYM_4  \
# 0  ICE DET (X) FAIL - STATUS  DEFERRED - REPLACED...        NaN      3081
# 1     TRU FAN FAIL - STATUS  DEFERRED - REPLACED TRU        NaN      2431
# 2      ISOL FAIL - CAUTION  REPLACED ISOLATION VALVE        NaN      3613
# 3  Incident: RTRN L COWL ANTI ICE CAUTION MSG. L ...        NaN      3022
# 4  Incident: RTRN OVBD COOL CAUTION MESSAGE DISPL...        NaN      2131
#
#    ATA_CAUSE_4
# 0         3081
# 1         2431
# 2         3613
# 3         3022
# 4         2131
#
# [5 rows x 26 columns]

# %%
#nltk.download('punkt')
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
def identify_tokens1(df):
    comment = df['features']
    comment = re.sub(r'\W',' ',comment)
    comment = re.sub(r'\s+',' ', comment)
    words = nltk.word_tokenize(comment)
    new_words = [stemmer.stem(word) for word in words]
    comment = ' '.join(new_words)
    return comment

df2['features_1'] = df2.apply(identify_tokens1, axis=1)

# %%
df2.head(20)
# Out:
#     ATA_SYMPTOM  ATA_CAUSE                                INTERRUPTION_REASON  \
# 0        3081.0     308102                          ICE DET (X) FAIL - STATUS
# 1        2431.0     243101                              TRU FAN FAIL - STATUS
# 2        3613.0     361315                                ISOL FAIL - CAUTION
# 3        3022.0     302201  Incident: RTRN L COWL ANTI ICE CAUTION MSG. L ...
# 4      213108.0     213108  Incident: RTRN OVBD COOL CAUTION MESSAGE DISPL...
# 5        5270.0       5270  Incident: ABRT R AFT EMER DOOR CAUTION MSG DUR...
# 6         240.0     212212  ON TAKEOFF, UPON ADDING TAKEOFF THRUST WE NOTI...
# 7        3261.0     326105  PRX SYS FAULT 1 after T/off When Flaps put up....
# 8        3152.0       3152  REJECTED TAKE OFF (APPROX 60 KTS) PANEL LIGHTS...
# 9      561101.0     561101  L WINDSHIELD HEAT CAUTION AT FL 330 IN CRUISE ...
# 10       3251.0     325150                            STEERING INOP - CAUTION
# 11       3042.0     304207                              WINDSHIELD WIPER INOP
# 12       3012.0     301206                            WING A/I FAULT - STATUS
# 13          0.0          0                               Reason: DUMMY RECORD
# 14          0.0          0                               Reason: DUMMY RECORD
# 15          0.0          0                               Reason: DUMMY RECORD
# 16          0.0          0                               Reason: DUMMY RECORD
# 17        240.0     332109            ELECTRICAL BURNING SMELL IN FIRST CLASS
# 18       3231.0       3231               GEAR UP DISAGREE WARNING-RTG-SDR-MIS
# 19       5270.0     527002              RTG PROX SYS FAULLT 2 SVC DOOR SENSOR
#
#                                     CORRECTIVE_ACTION  Unnamed: 0 FI_DATE  \
# 0                    DEFERRED - REPLACED ICE DETECTOR         NaN     NaN
# 1                             DEFERRED - REPLACED TRU         NaN     NaN
# 2                            REPLACED ISOLATION VALVE         NaN     NaN
# 3   (Resolved On W/O: 684248 Taskcard: NR-00001 ) ...         NaN     NaN
# 4   (Resolved On W/O: 684350 Taskcard: NR-00001 ) ...         NaN     NaN
# 5   (Resolved On W/O: 684680 Taskcard: NR-00002 ) ...         NaN     NaN
# 6   PERFORMED TROUBLESHOOTING TO AVIONICS EXHAUST ...         NaN     NaN
# 7   FOUND B1#007442(PX03 WAS OUT OF RIG@.116)(PX11...         NaN     NaN
# 8   PERFORMED OPS CHECK OF WARNING LIGHT SYSTEM IA...         NaN     NaN
# 9   REMOVED AND REPLACED L WINDSHIELD IAW JOBCARD ...         NaN     NaN
# 10                         REPLACED STEERING MANIFOLD         NaN     NaN
# 11                DEFERRED - REPLACED CONVERTER/MOTOR         NaN     NaN
# 12                                    REPLACED SENSOR         NaN     NaN
# 13                                                NaN         NaN     NaN
# 14                                                NaN         NaN     NaN
# 15                                                NaN         NaN     NaN
# 16                                                NaN         NaN     NaN
# 17  REMOVED AND REPLACED SIDEWALL LIGHT BALLAST AT...         NaN     NaN
# 18      PERFORMED GEAR SWING OPS TEST. OPS TEST GOOD.         NaN     NaN
# 19                   cleaned px38. ops normal. 56500.         NaN     NaN
#
#    AC_MODEL  AC_SN OPERATOR_CODE DELAY  ... SCHED_DEPARTURE_TIME  \
# 0       NaN    NaN           NaN   NaN  ...                  NaN
# 1       NaN    NaN           NaN   NaN  ...                  NaN
# 2       NaN    NaN           NaN   NaN  ...                  NaN
# 3       NaN    NaN           NaN   NaN  ...                  NaN
# 4       NaN    NaN           NaN   NaN  ...                  NaN
# 5       NaN    NaN           NaN   NaN  ...                  NaN
# 6       NaN    NaN           NaN   NaN  ...                  NaN
# 7       NaN    NaN           NaN   NaN  ...                  NaN
# 8       NaN    NaN           NaN   NaN  ...                  NaN
# 9       NaN    NaN           NaN   NaN  ...                  NaN
# 10      NaN    NaN           NaN   NaN  ...                  NaN
# 11      NaN    NaN           NaN   NaN  ...                  NaN
# 12      NaN    NaN           NaN   NaN  ...                  NaN
# 13      NaN    NaN           NaN   NaN  ...                  NaN
# 14      NaN    NaN           NaN   NaN  ...                  NaN
# 15      NaN    NaN           NaN   NaN  ...                  NaN
# 16      NaN    NaN           NaN   NaN  ...                  NaN
# 17      NaN    NaN           NaN   NaN  ...                  NaN
# 18      NaN    NaN           NaN   NaN  ...                  NaN
# 19      NaN    NaN           NaN   NaN  ...                  NaN
#
#     ACTUAL_DEPARTURE_TIME INTERRUPTION_CODE FI_ID  EDITED_BY EDIT_DATE  \
# 0                     NaN               NaN   NaN        NaN       NaN
# 1                     NaN               NaN   NaN        NaN       NaN
# 2                     NaN               NaN   NaN        NaN       NaN
# 3                     NaN               NaN   NaN        NaN       NaN
# 4                     NaN               NaN   NaN        NaN       NaN
# 5                     NaN               NaN   NaN        NaN       NaN
# 6                     NaN               NaN   NaN        NaN       NaN
# 7                     NaN               NaN   NaN        NaN       NaN
# 8                     NaN               NaN   NaN        NaN       NaN
# 9                     NaN               NaN   NaN        NaN       NaN
# 10                    NaN               NaN   NaN        NaN       NaN
# 11                    NaN               NaN   NaN        NaN       NaN
# 12                    NaN               NaN   NaN        NaN       NaN
# 13                    NaN               NaN   NaN        NaN       NaN
# 14                    NaN               NaN   NaN        NaN       NaN
# 15                    NaN               NaN   NaN        NaN       NaN
# 16                    NaN               NaN   NaN        NaN       NaN
# 17                    NaN               NaN   NaN        NaN       NaN
# 18                    NaN               NaN   NaN        NaN       NaN
# 19                    NaN               NaN   NaN        NaN       NaN
#
#                                              features  \
# 0   ICE DET (X) FAIL - STATUS  DEFERRED - REPLACED...
# 1      TRU FAN FAIL - STATUS  DEFERRED - REPLACED TRU
# 2       ISOL FAIL - CAUTION  REPLACED ISOLATION VALVE
# 3   Incident: RTRN L COWL ANTI ICE CAUTION MSG. L ...
# 4   Incident: RTRN OVBD COOL CAUTION MESSAGE DISPL...
# 5   Incident: ABRT R AFT EMER DOOR CAUTION MSG DUR...
# 6   ON TAKEOFF, UPON ADDING TAKEOFF THRUST WE NOTI...
# 7   PRX SYS FAULT 1 after T/off When Flaps put up....
# 8   REJECTED TAKE OFF (APPROX 60 KTS) PANEL LIGHTS...
# 9   L WINDSHIELD HEAT CAUTION AT FL 330 IN CRUISE ...
# 10  STEERING INOP - CAUTION  REPLACED STEERING MAN...
# 11  WINDSHIELD WIPER INOP  DEFERRED - REPLACED CON...
# 12           WING A/I FAULT - STATUS  REPLACED SENSOR
# 13                            Reason: DUMMY RECORD
# 14                            Reason: DUMMY RECORD
# 15                            Reason: DUMMY RECORD
# 16                            Reason: DUMMY RECORD
# 17  ELECTRICAL BURNING SMELL IN FIRST CLASS  REMOV...
# 18  GEAR UP DISAGREE WARNING-RTG-SDR-MIS  PERFORME...
# 19  RTG PROX SYS FAULLT 2 SVC DOOR SENSOR  cleaned...
#
#                                            features_1 ATA_SYM_4  ATA_CAUSE_4
# 0      ice det X fail statu defer replac ice detector      3081         3081
# 1                 tru fan fail statu defer replac tru      2431         2431
# 2                  isol fail caution replac isol valv      3613         3613
# 3   incid rtrn L cowl anti ice caution msg L cowl ...      3022         3022
# 4   incid rtrn ovbd cool caution messag display gr...      2131         2131
# 5   incid abrt R aft emer door caution msg dure ta...      5270         5270
# 6   ON takeoff upon ad takeoff thrust WE notic A s...      240.         2122
# 7   prx sy fault 1 after T off when flap put up ms...      3261         3261
# 8   reject take off approx 60 kt panel light activ...      3152         3152
# 9   L windshield heat caution AT FL 330 IN cruis f...      5611         5611
# 10           steer inop caution replac steer manifold      3251         3251
# 11   windshield wiper inop defer replac convert motor      3042         3042
# 12                 wing A I fault statu replac sensor      3012         3012
# 13                                reason dummi record       0.0            0
# 14                                reason dummi record       0.0            0
# 15                                reason dummi record       0.0            0
# 16                                reason dummi record       0.0            0
# 17  electr burn smell IN first class remov and rep...      240.         3321
# 18  gear UP disagre warn rtg sdr mi perform gear s...      3231         3231
# 19  rtg prox sy faullt 2 svc door sensor clean px3...      5270         5270
#
# [20 rows x 26 columns]

# %%
df2_ATA_SYM = df2.dropna(axis=0, subset=['ATA_SYMPTOM'])

# %%
len(df2_ATA_SYM)
# Out:
# 376420

# %%
from sklearn.model_selection import train_test_split
X = df2_ATA_SYM['features_1']
y = df2_ATA_SYM['ATA_SYM_4']
#y = df2_ATA_SYM['ATA_SYMPTOM']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.pipeline import Pipeline
text_clf = Pipeline([('tfidf',TfidfVectorizer(sublinear_tf=False,ngram_range=(1,2),stop_words='english')),('clf',CalibratedClassifierCV(LinearSVC()))])
text_clf.fit(X_train,y_train)
# Out:
# D:\Programs\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-11-4e746ca2876f> in <module>
#       4 from sklearn.pipeline import Pipeline
#       5 text_clf = Pipeline([('tfidf',TfidfVectorizer(sublinear_tf=False,ngram_range=(1,2),stop_words='english')),('clf',CalibratedClassifierCV(LinearSVC()))])
# ----> 6 text_clf.fit(X_train,y_train)
#
# D:\Programs\anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     333             if self._final_estimator != 'passthrough':
#     334                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 335                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     336
#     337         return self
#
# D:\Programs\anaconda3\lib\site-packages\sklearn\calibration.py in fit(self, X, y, sample_weight)
#     176                                        sample_weight=sample_weight[train])
#     177                 else:
# --> 178                     this_estimator.fit(X[train], y[train])
#     179
#     180                 calibrated_classifier = _CalibratedClassifier(
#
# D:\Programs\anaconda3\lib\site-packages\sklearn\svm\_classes.py in fit(self, X, y, sample_weight)
#     231         self.classes_ = np.unique(y)
#     232
# --> 233         self.coef_, self.intercept_, self.n_iter_ = _fit_liblinear(
#     234             X, y, self.C, self.fit_intercept, self.intercept_scaling,
#     235             self.class_weight, self.penalty, self.dual, self.verbose,
#
# D:\Programs\anaconda3\lib\site-packages\sklearn\svm\_base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     964
#     965     solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
# --> 966     raw_coef_, n_iter_ = liblinear.train_wrap(
#     967         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     968         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
#
# sklearn\svm\_liblinear.pyx in sklearn.svm._liblinear.train_wrap()
#
# MemoryError: Unable to allocate 4.34 GiB for an array with shape (479, 1215591) and data type float64

# %%
from sklearn import metrics
predictions = text_clf.predict(X_test)
metrics.accuracy_score(y_test,predictions)
# Out:
# 0.6783380266723341

# %%
# import pickle
# pkl_filename = "crj700_all.pkl"
# with open(text_clf.best_estimator_, 'wb') as file:
#     pickle.dump(text_clf.best_estimator_, file)

# # Load from file
# with open(pkl_filename, 'rb') as file:
#     pickle_model = pickle.load(file)

#from sklearn.externals import joblib
import joblib
joblib.dump(text_clf, 'crj700_all_ATA_SYM_4.pkl')

# Load from file
joblib_model = joblib.load(crj700_all.pkl)
# Out:
# ['crj700_all.pkl']

# %%
predictions_prob = pd.DataFrame(text_clf.predict_proba(X_test),columns=text_clf.classes_)

# %%
ata_sym_top3 = lambda row, nlargest=3:sorted(pd.Series(zip(predictions_prob.columns, row)), key=lambda cv: -cv[1]) [:nlargest]

tmp = predictions_prob.apply(ata_sym_top3, axis=1)
result = pd.DataFrame(list(map(np.ravel, tmp)))
result
# Out:
#               0         1         2         3         4         5
# 0      362101.0  0.426999    3621.0  0.364787     520.0  0.028727
# 1        3451.0  0.428802     520.0  0.116625     200.0  0.085338
# 2      256115.0  0.611514  256102.0  0.254101    2561.0  0.021510
# 3         200.0  0.776070     520.0  0.020609    2351.0  0.008119
# 4        3161.0  0.599510  316101.0  0.156359     200.0  0.026310
# ...         ...       ...       ...       ...       ...       ...
# 37637    1200.0  0.590309  322101.0  0.282500  324201.0  0.046306
# 37638    4931.0  0.799156    4961.0  0.019171    4920.0  0.011586
# 37639    2825.0  0.549102  282517.0  0.102228     240.0  0.036231
# 37640     240.0  0.892164    3221.0  0.008641    3261.0  0.005771
# 37641    7831.0  0.696840  783001.0  0.100086  783203.0  0.040234
#
# [37642 rows x 6 columns]

# %%
result.to_csv("temp.csv",index=False,quoting=3,sep=',',escapechar='\\')

# %%
output=pd.DataFrame(data={"Real":y_test,"prediction":predictions,"Features_Preprocessed":X_test}) 
#output
output.to_csv("Prediction_ALL_ATA_SYM_CRJ700_TOP3_0415.csv",index=False,quoting=3,sep=',',escapechar='\\')

# %% [markdown]
# ATA_CAUSE

# %%
y
# Out:
# 0         3081
# 1         2431
# 2         3613
# 3         3022
# 4         2131
#           ...
# 394812    240.
# 394813    2511
# 394814    200.
# 394815    520.
# 394816    2522
# Name: ATA_SYM_4, Length: 376420, dtype: object

# %%
from sklearn.model_selection import train_test_split
X = df2['features_1']
#y = df2['ATA_CAUSE']
y = df2['ATA_CAUSE_4']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.pipeline import Pipeline
text_clf = Pipeline([('tfidf',TfidfVectorizer(sublinear_tf=False,ngram_range=(1,2),stop_words='english')),('clf',CalibratedClassifierCV(LinearSVC()))])
text_clf.fit(X_train,y_train)
# Out:
# D:\Programs\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_features=9000, stop_words='english')),
#                 ('clf', CalibratedClassifierCV(base_estimator=LinearSVC()))])

# %%
predictions = text_clf.predict(X_test)
metrics.accuracy_score(y_test,predictions)
# Out:
# 0.7403120409300441

# %%
joblib.dump(text_clf, 'crj_all.pkl')
# Out:
# ['crj_all.pkl']

# %%
predictions_prob = pd.DataFrame(text_clf.predict_proba(X_test),columns=text_clf.classes_)

# %%
ata_sym_top3 = lambda row, nlargest=3:sorted(pd.Series(zip(predictions_prob.columns, row)), key=lambda cv: -cv[1]) [:nlargest]

tmp = predictions_prob.apply(ata_sym_top3, axis=1)
result = pd.DataFrame(list(map(np.ravel, tmp)))
result
# Out:
#               0         1         2         3         4         5
# 0        2151.0  0.403996  215101.0  0.062453    2825.0  0.034624
# 1      278133.0  0.559895    2781.0  0.263984  275105.0  0.059847
# 2      801101.0  0.789220  801103.0  0.037852    3613.0  0.021693
# 3         200.0  0.723175     520.0  0.019175     550.0  0.011327
# 4      308102.0  0.318103     200.0  0.089431     240.0  0.081476
# ...         ...       ...       ...       ...       ...       ...
# 39477    2331.0  0.849384    2351.0  0.018256     200.0  0.017679
# 39478  252101.0  0.866949    5231.0  0.007801    5211.0  0.005843
# 39479     200.0  0.719441  282506.0  0.041437    7200.0  0.017052
# 39480    2322.0  0.549586    2311.0  0.317341  231101.0  0.017103
# 39481  772101.0  0.775403  303205.0  0.118788    7721.0  0.027993
#
# [39482 rows x 6 columns]

# %%
result.to_csv("temp.csv",index=False,quoting=3,sep=',',escapechar='\\')

# %%
output=pd.DataFrame(data={"Real":y_test,"prediction":predictions,"Features_Preprocessed":X_test}) 
#output
output.to_csv("Prediction_ALL_ATA_CAUSE_CRJ700_TOP3_0415.csv",index=False,quoting=3,sep=',',escapechar='\\')
